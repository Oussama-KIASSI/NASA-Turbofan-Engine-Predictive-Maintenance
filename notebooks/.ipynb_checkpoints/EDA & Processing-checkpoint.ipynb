# %%
import sys
sys.path.insert(1, '../src')

import utils
import pandas as pd
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 40)
import re

# %%
dataschema = ['Engine_no', 'Time', 'Altitude', 'Mach', 'TRA', 'T2', 'T24', 
              'T30', 'T50', 'P2', 'P15', 'P30', 'Nf', 'Nc', 'epr', 'Ps30', 
              'phi', 'NRf', 'NRc', 'BPR', 'farB', 'htBleed', 'Nf_dmd', 
              'PCNfR_dmd', 'W31', 'W32']
dataframes = utils.load_data('RUL', ["RUL"], dataschema)
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
# ------------------------------
# ----------RUL_FD001-----------
# ------------------------------
# Number of rows : 100
# Number of columns : 1
#
# ------------------------------
# ----------RUL_FD002-----------
# ------------------------------
# Number of rows : 259
# Number of columns : 1
#
# ------------------------------
# ----------RUL_FD003-----------
# ------------------------------
# Number of rows : 100
# Number of columns : 1
#
# ------------------------------
# ----------RUL_FD004-----------
# ------------------------------
# Number of rows : 248
# Number of columns : 1
#
# ------------------------------
# ----------test_FD001----------
# ------------------------------
# Number of rows : 13096
# Number of columns : 26
#
# ------------------------------
# ----------test_FD002----------
# ------------------------------
# Number of rows : 33991
# Number of columns : 26
#
# ------------------------------
# ...

# %%
dataframes['test_FD001'].head()
# Out:
#    Engine_no  Time  Altitude    Mach    TRA      T2     T24      T30      T50  \
# 0          1     1    0.0023  0.0003  100.0  518.67  643.02  1585.29  1398.21
# 1          1     2   -0.0027 -0.0003  100.0  518.67  641.71  1588.45  1395.42
# 2          1     3    0.0003  0.0001  100.0  518.67  642.46  1586.94  1401.34
# 3          1     4    0.0042  0.0000  100.0  518.67  642.44  1584.12  1406.42
# 4          1     5    0.0014  0.0000  100.0  518.67  642.51  1587.19  1401.92
#
#       P2    P15     P30       Nf       Nc  epr   Ps30     phi      NRf  \
# 0  14.62  21.61  553.90  2388.04  9050.17  1.3  47.20  521.72  2388.03
# 1  14.62  21.61  554.85  2388.01  9054.42  1.3  47.50  522.16  2388.06
# 2  14.62  21.61  554.11  2388.05  9056.96  1.3  47.50  521.97  2388.03
# 3  14.62  21.61  554.07  2388.03  9045.29  1.3  47.28  521.38  2388.05
# 4  14.62  21.61  554.16  2388.01  9044.55  1.3  47.31  522.15  2388.03
#
#        NRc     BPR  farB  htBleed  Nf_dmd  PCNfR_dmd    W31      W32
# ...

# %%
df = dataframes['test_FD001']

# %%
def feature_extraction(df):
    df['RUL'] = df.groupby('Engine_no')['Time'].transform('max') - df['Time'] + 1
    return df

# %%
feature_extraction(df)
# Out:
#        Engine_no  Time  Altitude    Mach    TRA      T2     T24      T30  \
# 0              1     1    0.0023  0.0003  100.0  518.67  643.02  1585.29
# 1              1     2   -0.0027 -0.0003  100.0  518.67  641.71  1588.45
# 2              1     3    0.0003  0.0001  100.0  518.67  642.46  1586.94
# 3              1     4    0.0042  0.0000  100.0  518.67  642.44  1584.12
# 4              1     5    0.0014  0.0000  100.0  518.67  642.51  1587.19
# ...          ...   ...       ...     ...    ...     ...     ...      ...
# 13091        100   194    0.0049  0.0000  100.0  518.67  643.24  1599.45
# 13092        100   195   -0.0011 -0.0001  100.0  518.67  643.22  1595.69
# 13093        100   196   -0.0006 -0.0003  100.0  518.67  643.44  1593.15
# 13094        100   197   -0.0038  0.0001  100.0  518.67  643.26  1594.99
# 13095        100   198    0.0013  0.0003  100.0  518.67  642.95  1601.62
#
#            T50     P2    P15     P30       Nf       Nc  epr   Ps30     phi  \
# ...

# %%
df.loc[:,['Engine_no', 'Time', 'RUL']].head(35)
# Out:
#     Engine_no  Time  RUL
# 0           1     1   31
# 1           1     2   30
# 2           1     3   29
# 3           1     4   28
# 4           1     5   27
# 5           1     6   26
# 6           1     7   25
# 7           1     8   24
# 8           1     9   23
# 9           1    10   22
# 10          1    11   21
# 11          1    12   20
# 12          1    13   19
# 13          1    14   18
# 14          1    15   17
# 15          1    16   16
# 16          1    17   15
# 17          1    18   14
# 18          1    19   13
# 19          1    20   12
# 20          1    21   11
# 21          1    22   10
# 22          1    23    9
# 23          1    24    8
# 24          1    25    7
# 25          1    26    6
# 26          1    27    5
# 27          1    28    4
# 28          1    29    3
# 29          1    30    2
# 30          1    31    1
# 31          2     1   49
# 32          2     2   48
# 33          2     3   47
# 34          2     4   46
